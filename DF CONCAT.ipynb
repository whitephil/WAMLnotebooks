# %%
import pandas as pd

# %%
NevCos = pd.read_csv('Data/Nevada_Counties.csv')

# %%
CalCos = pd.read_csv('Data/California_Counties.csv', converters={'FIPS': lambda x: str(x)})

# %%
CalCos
# Out:
#             FIPS                                       Name of Area  \
# 0    06017030200     Census Tract 302, El Dorado County, California
# 1    06017030301  Census Tract 303.01, El Dorado County, California
# 2    06017030302  Census Tract 303.02, El Dorado County, California
# 3    06017030401  Census Tract 304.01, El Dorado County, California
# 4    06017030402  Census Tract 304.02, El Dorado County, California
# ..           ...                                                ...
# 123  06061023600        Census Tract 236, Placer County, California
# 124  06061023700        Census Tract 237, Placer County, California
# 125  06061023800        Census Tract 238, Placer County, California
# 126  06061023900        Census Tract 239, Placer County, California
# 127  06061990000       Census Tract 9900, Placer County, California
#
#                                        Qualifying Name  \
# 0       Census Tract 302, El Dorado County, California
# ...

# %%
NevCos
# Out:
#             FIPS                              Name of Area  \
# 0    32005001000   Census Tract 10, Douglas County, Nevada
# 1    32005001100   Census Tract 11, Douglas County, Nevada
# 2    32005001200   Census Tract 12, Douglas County, Nevada
# 3    32005001300   Census Tract 13, Douglas County, Nevada
# 4    32005001400   Census Tract 14, Douglas County, Nevada
# ..           ...                                       ...
# 124  32031980100  Census Tract 9801, Washoe County, Nevada
# 125  32031980200  Census Tract 9802, Washoe County, Nevada
# 126  32031980300  Census Tract 9803, Washoe County, Nevada
# 127  32031990000  Census Tract 9900, Washoe County, Nevada
# 128  32031990100  Census Tract 9901, Washoe County, Nevada
#
#                               Qualifying Name State/U.S.-Abbreviation (USPS)  \
# 0     Census Tract 10, Douglas County, Nevada                             nv
# 1     Census Tract 11, Douglas County, Nevada                             nv
# ...

# %%
All_Counties = pd.concat([NevCos, CalCos])

# %%
All_Counties
# Out:
#             FIPS Geographic Identifier  \
# 0    32005001000    14000US32005001000
# 1    32005001100    14000US32005001100
# 2    32005001200    14000US32005001200
# 3    32005001300    14000US32005001300
# 4    32005001400    14000US32005001400
# ..           ...                   ...
# 123   6061023600    14000US06061023600
# 124   6061023700    14000US06061023700
# 125   6061023800    14000US06061023800
# 126   6061023900    14000US06061023900
# 127   6061990000    14000US06061990000
#
#                                      Name of Area  \
# 0         Census Tract 10, Douglas County, Nevada
# 1         Census Tract 11, Douglas County, Nevada
# 2         Census Tract 12, Douglas County, Nevada
# 3         Census Tract 13, Douglas County, Nevada
# 4         Census Tract 14, Douglas County, Nevada
# ..                                            ...
# 123   Census Tract 236, Placer County, California
# 124   Census Tract 237, Placer County, California
# ...

# %%
All_Counties = All_Counties.rename(columns={'FIPS':'GEOID'})

# %%
All_Counties
# Out:
#            GEOID                                  Name of Area  \
# 0    32005001000       Census Tract 10, Douglas County, Nevada
# 1    32005001100       Census Tract 11, Douglas County, Nevada
# 2    32005001200       Census Tract 12, Douglas County, Nevada
# 3    32005001300       Census Tract 13, Douglas County, Nevada
# 4    32005001400       Census Tract 14, Douglas County, Nevada
# ..           ...                                           ...
# 123  06061023600   Census Tract 236, Placer County, California
# 124  06061023700   Census Tract 237, Placer County, California
# 125  06061023800   Census Tract 238, Placer County, California
# 126  06061023900   Census Tract 239, Placer County, California
# 127  06061990000  Census Tract 9900, Placer County, California
#
#                                   Qualifying Name  \
# 0         Census Tract 10, Douglas County, Nevada
# 1         Census Tract 11, Douglas County, Nevada
# 2         Census Tract 12, Douglas County, Nevada
# ...

# %%
All_Counties.set_index('GEOID', inplace = True)

# %%
All_Counties
# Out:
#                                              Name of Area  \
# GEOID
# 32005001000       Census Tract 10, Douglas County, Nevada
# 32005001100       Census Tract 11, Douglas County, Nevada
# 32005001200       Census Tract 12, Douglas County, Nevada
# 32005001300       Census Tract 13, Douglas County, Nevada
# 32005001400       Census Tract 14, Douglas County, Nevada
# ...                                                   ...
# 06061023600   Census Tract 236, Placer County, California
# 06061023700   Census Tract 237, Placer County, California
# 06061023800   Census Tract 238, Placer County, California
# 06061023900   Census Tract 239, Placer County, California
# 06061990000  Census Tract 9900, Placer County, California
#
#                                           Qualifying Name  \
# GEOID
# 32005001000       Census Tract 10, Douglas County, Nevada
# 32005001100       Census Tract 11, Douglas County, Nevada
# 32005001200       Census Tract 12, Douglas County, Nevada
# ...

# %%
All_Counties.dtypes
# Out:
# Name of Area                                                                         object
# Qualifying Name                                                                      object
# State/U.S.-Abbreviation (USPS)                                                       object
# Summary Level                                                                         int64
# Geographic Component                                                                  int64
#                                                                                       ...
# Population for Whom Poverty Status Is Determined:                                     int64
# Population for Whom Poverty Status Is Determined: Under 1.00 (Doing Poorly)           int64
# Population for Whom Poverty Status Is Determined: 1.00 to 1.99 (Struggling)           int64
# Population for Whom Poverty Status Is Determined: Under 2.00 (Poor or Struggling)     int64
# ...

# %%
All_Counties.to_csv('Data/All_Counties.csv')
