# %%
import pandas as pd

# %%
Cal_Cos = pd.read_csv('Data/California_Tahoe_Counties_raw.csv')

# %%
Cal_Cos
# Out:
#             FIPS                                       Name of Area  \
# 0       Geo_FIPS                                           Geo_NAME
# 1    06017030200     Census Tract 302, El Dorado County, California
# 2    06017030301  Census Tract 303.01, El Dorado County, California
# 3    06017030302  Census Tract 303.02, El Dorado County, California
# 4    06017030401  Census Tract 304.01, El Dorado County, California
# ..           ...                                                ...
# 124  06061023600        Census Tract 236, Placer County, California
# 125  06061023700        Census Tract 237, Placer County, California
# 126  06061023800        Census Tract 238, Placer County, California
# 127  06061023900        Census Tract 239, Placer County, California
# 128  06061990000       Census Tract 9900, Placer County, California
#
#                                        Qualifying Name  \
# 0                                            Geo_QName
# ...

# %%
Cal_Cos = Cal_Cos.drop([0])

# %%
Cal_Cos
# Out:
#             FIPS                                       Name of Area  \
# 1    06017030200     Census Tract 302, El Dorado County, California
# 2    06017030301  Census Tract 303.01, El Dorado County, California
# 3    06017030302  Census Tract 303.02, El Dorado County, California
# 4    06017030401  Census Tract 304.01, El Dorado County, California
# 5    06017030402  Census Tract 304.02, El Dorado County, California
# ..           ...                                                ...
# 124  06061023600        Census Tract 236, Placer County, California
# 125  06061023700        Census Tract 237, Placer County, California
# 126  06061023800        Census Tract 238, Placer County, California
# 127  06061023900        Census Tract 239, Placer County, California
# 128  06061990000       Census Tract 9900, Placer County, California
#
#                                        Qualifying Name  \
# 1       Census Tract 302, El Dorado County, California
# ...

# %%
Cal_Cos.dtypes
# Out:
# FIPS                                                                                 object
# Name of Area                                                                         object
# Qualifying Name                                                                      object
# State/U.S.-Abbreviation (USPS)                                                       object
# Summary Level                                                                        object
#                                                                                       ...
# Population for Whom Poverty Status Is Determined:                                    object
# Population for Whom Poverty Status Is Determined: Under 1.00 (Doing Poorly)          object
# Population for Whom Poverty Status Is Determined: 1.00 to 1.99 (Struggling)          object
# Population for Whom Poverty Status Is Determined: Under 2.00 (Poor or Struggling)    object
# ...

# %%
Cal_Cos = Cal_Cos.set_index('FIPS')

# %%
Cal_Cos.to_csv('Data/California_Counties.csv')

# %%
Nev_Cos = pd.read_csv('Data/Nevada_Tahoe_Counties_raw.csv')

# %%
Nev_Cos = Nev_Cos.drop([0])

# %%
Nev_Cos = Nev_Cos.set_index('FIPS')

# %%
Nev_Cos.to_csv('Data/Nevada_Counties.csv')

# %%
pd.read_csv('Data/California_Counties.csv') #note the stipped leading zero in 'FIPS'
# Out:
#            FIPS                                       Name of Area  \
# 0    6017030200     Census Tract 302, El Dorado County, California
# 1    6017030301  Census Tract 303.01, El Dorado County, California
# 2    6017030302  Census Tract 303.02, El Dorado County, California
# 3    6017030401  Census Tract 304.01, El Dorado County, California
# 4    6017030402  Census Tract 304.02, El Dorado County, California
# ..          ...                                                ...
# 123  6061023600        Census Tract 236, Placer County, California
# 124  6061023700        Census Tract 237, Placer County, California
# 125  6061023800        Census Tract 238, Placer County, California
# 126  6061023900        Census Tract 239, Placer County, California
# 127  6061990000       Census Tract 9900, Placer County, California
#
#                                        Qualifying Name  \
# 0       Census Tract 302, El Dorado County, California
# ...
