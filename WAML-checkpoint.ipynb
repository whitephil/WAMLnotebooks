# %% [markdown]
# ### Introduction to Python for Map Librarians
#
# __Data Types__
#
# * Numbers
# * Strings
# * Lists
# * Dictionaries
# * Tuples
#
# __Packages__
#
# Python libraries consist of various packages. These external sources can be leveraged in code by using the *import* command

# %%
import time
print (time.ctime())
# Out:
# Tue Aug 13 08:32:36 2019

# %% [markdown]
# __Variables__
#
# Containers for storing data values. Values are assigned to a variable using the equals '=' sign.

# %%
myname = 'Joe'
print (myname)
# Out:
# Joe

# %% [markdown]
# __Reading Files__
#
# Reading a _.csv_ file into a dataframe

# %%
import pandas

index = pandas.read_csv('JMMindex.csv')
index
# Out:
#     Sheet_Num              Sheet_ID     Call_Short     Symph_Bar  \
# 0       BHH-8   G7900 S50 .J3 BHH-8  G7900 S50 .J3  3.610000e+13
# 1       BHH-4   G7900 S50 .J3 BHH-4  G7900 S50 .J3  3.610000e+13
# 2      BEE-16  G7900 S50 .J3 BEE-16  G7900 S50 .J3  3.610000e+13
# 3      BEE-12  G7900 S50 .J3 BEE-12  G7900 S50 .J3  3.610000e+13
# 4       BEE-8   G7900 S50 .J3 BEE-8  G7900 S50 .J3  3.610000e+13
# ..        ...                   ...            ...           ...
# 475      BD-2    G7900 S50 .J3 BD-2  G7900 S50 .J3  0.000000e+00
# 476     BD-13   G7900 S50 .J3 BD-13  G7900 S50 .J3  0.000000e+00
# 477      BD-9    G7900 S50 .J3 BD-9  G7900 S50 .J3  0.000000e+00
# 478      BD-5    G7900 S50 .J3 BD-5  G7900 S50 .J3  0.000000e+00
# 479      BD-1    G7900 S50 .J3 BD-1  G7900 S50 .J3  0.000000e+00
#
#                  Call_Num                     Label        Druid  \
# 0     G7900 S50 .J3 BHH-8  Chosen 1:50,000 Chikeizu  qc800wv3208
# 1     G7900 S50 .J3 BHH-4  Chosen 1:50,000 Chikeizu  ww737hs5709
# 2    G7900 S50 .J3 BEE-16  Chosen 1:50,000 Chikeizu  fw835qs6564
# 3    G7900 S50 .J3 BEE-12  Chosen 1:50,000 Chikeizu  wk141gq4821
# 4     G7900 S50 .J3 BEE-8  Chosen 1:50,000 Chikeizu  wb497vn4428
# ..                    ...                       ...          ...
# 475                   NaN                       NaN          NaN
# 476                   NaN                       NaN          NaN
# 477                   NaN                       NaN          NaN
# 478                   NaN                       NaN          NaN
# 479                   NaN                       NaN          NaN
#
#                                      Purl                       Title  \
# 0    http://purl.stanford.edu/qc800wv3208  [Chosen 1:50,000 Chikeizu]
# 1    http://purl.stanford.edu/ww737hs5709  [Chosen 1:50,000 Chikeizu]
# 2    http://purl.stanford.edu/fw835qs6564  [Chosen 1:50,000 Chikeizu]
# 3    http://purl.stanford.edu/wk141gq4821  [Chosen 1:50,000 Chikeizu]
# 4    http://purl.stanford.edu/wb497vn4428  [Chosen 1:50,000 Chikeizu]
# ..                                    ...                         ...
# 475                                   NaN                         NaN
# 476                                   NaN                         NaN
# 477                                   NaN                         NaN
# 478                                   NaN                         NaN
# 479                                   NaN                         NaN
#
#         Ckey  sheet                                            web_map
# 0    9585363      1  http://stanford.maps.arcgis.com/apps/SimpleVie...
# 1    9585363      1  http://stanford.maps.arcgis.com/apps/SimpleVie...
# 2    9585363      1  http://stanford.maps.arcgis.com/apps/SimpleVie...
# 3    9585363      1  http://stanford.maps.arcgis.com/apps/SimpleVie...
# 4    9585363      1  http://stanford.maps.arcgis.com/apps/SimpleVie...
# ..       ...    ...                                                ...
# 475        0      0  http://stanford.maps.arcgis.com/apps/SimpleVie...
# 476        0      0  http://stanford.maps.arcgis.com/apps/SimpleVie...
# 477        0      0  http://stanford.maps.arcgis.com/apps/SimpleVie...
# 478        0      0  http://stanford.maps.arcgis.com/apps/SimpleVie...
# 479        0      0  http://stanford.maps.arcgis.com/apps/SimpleVie...
#
# [480 rows x 12 columns]

# %% [markdown]
# __Finding Data__
#
# By column name

# %%
index["Sheet_Num"]
# Out:
# 0       BHH-8
# 1       BHH-4
# 2      BEE-16
# 3      BEE-12
# 4       BEE-8
#         ...
# 475      BD-2
# 476     BD-13
# 477      BD-9
# 478      BD-5
# 479      BD-1
# Name: Sheet_Num, Length: 480, dtype: object

# %% [markdown]
# __By column index__

# %%
index.iloc[ : , 0 ]
# Out:
# 0       BHH-8
# 1       BHH-4
# 2      BEE-16
# 3      BEE-12
# 4       BEE-8
#         ...
# 475      BD-2
# 476     BD-13
# 477      BD-9
# 478      BD-5
# 479      BD-1
# Name: Sheet_Num, Length: 480, dtype: object

# %% [markdown]
# __By row__

# %%
index.loc[ 2 , : ]
# Out:
# Sheet_Num                                                BEE-16
# Sheet_ID                                   G7900 S50 .J3 BEE-16
# Call_Short                                        G7900 S50 .J3
# Symph_Bar                                              3.61e+13
# Call_Num                                   G7900 S50 .J3 BEE-16
# Label                                  Chosen 1:50,000 Chikeizu
# Druid                                               fw835qs6564
# Purl                       http://purl.stanford.edu/fw835qs6564
# Title                                [Chosen 1:50,000 Chikeizu]
# Ckey                                                    9585363
# sheet                                                         1
# web_map       http://stanford.maps.arcgis.com/apps/SimpleVie...
# Name: 2, dtype: object

# %%
f2 = pandas.read_csv('Druids.csv')
f2
# Out:
#            Druid
# 0    bb571qd3933
# 1    bb624gz0574
# 2    bb933zb4329
# 3    bc336kw7428
# 4    bd179xg0542
# ..           ...
# 530  zv427rb9137
# 531  zv502vw0730
# 532  zw299mh7215
# 533  zx510nc5737
# 534  zx545jd0797
#
# [535 rows x 1 columns]

# %% [markdown]
# __Compare columns from the 2 datasets__

# %%
f2[~f2.Druid.isin(df.Druid)]
# Out:
#            Druid
# 10   bp560xv9016
# 11   bq310yr8491
# 13   bs075qt3622
# 16   bw374pg2631
# 19   bx561wy4675
# ..           ...
# 526  zp946gz3943
# 527  zq219jk5931
# 528  zs112fd7953
# 529  zt705qs6869
# 532  zw299mh7215
#
# [225 rows x 1 columns]

# %%
import geopandas
shp = geopandas.read_file('Sierra_Nevada_Yellowlegged_Frog_Critical_Habitat.shp')
shp
# Out:
#    OBJECTID                           COMNAME       SCINAME SPCODE VIPCODE  \
# 0         1  Sierra Nevada Yellow-Legged Frog  Rana sierrae   DO4M     V01
# 1         2  Sierra Nevada Yellow-Legged Frog  Rana sierrae   DO4M     V01
# 2         3  Sierra Nevada Yellow-Legged Frog  Rana sierrae   DO4M     V01
#
#   UNIT SUBUNIT UNITNAME     SUBUNITNAM STATUS  ...     FEDREG   PUBDATE  \
# 0    2      2E     None  Crystal Range  FINAL  ...  81FR59045  20160826
# 1    2      2D     None     Five Lakes  FINAL  ...  81FR59045  20160826
# 2    2      2F     None    East Amador  FINAL  ...  81FR59045  20160826
#
#   EFFECTDATE VACATEDATE ACCURACY SINGLMULTI COOPOFMORE    SHAPESTAre  \
# 0   20160926       None     None     SINGLE       None  3.366633e+08
# 1   20160926       None     None     SINGLE       None  3.757999e+07
# 2   20160926       None     None     SINGLE       None  4.404673e+08
#
#       SHAPESTLen                                           geometry
# 0  144160.701472  POLYGON ((743694.8531219075 4300373.509867072,...
# 1   38256.099257  POLYGON ((740316.7804780342 4338443.225799721,...
# 2  166260.376586  POLYGON ((762328.6737542534 4286515.411048507,...
#
# [3 rows x 22 columns]

# %% [markdown]
# __Loops__
